# %% [markdown]
# # BLUE TEAM

# %% [markdown]
# #Image classification/ recognition using tensorflow.
#
# Aim: Classify the image to the category it belongs to using:
# *   Deep learning algorithm for image classifcation: MobileNet2
#
# *   Image classification dataset: ImageNet

# %% [markdown]
# # 4 phrases of deep learning
# - Create a model
# - Training a model
# - Test or validate
# - Predict

# %% [markdown]
# ##Import the libraries

# %%
import tensorflow as tf
import numpy as np
from PIL import Image #Python image library
import matplotlib.pyplot as plt #plotting library
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import imagenet_utils

# %%
#!pip install tensorflow

# %%
filename = 'mouse1.jpg'

# %% [markdown]
# ## Load an image

# %%
img = Image.open(filename) # PIL
#resizing an image
img = img.resize((224, 224))

# %%
plt.imshow(img);

# %% [markdown]
# # Load the deep learning model

# %% [markdown]
# Pre-trained deep learning model

# %% [markdown]
# Tested on MobileNet - it is an older model from 2017 and the accuracy needs improvement.

# %%
#mobile = tf.keras.applications.mobilenet.MobileNet() #deep learning model weights - pre-trained

# %% [markdown]
# Tested on MobileNetV2 mobile, this model is from 2019 and also needs the accuracy to be improved

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2() #deep learning model weights - pre-trained

# %% [markdown]
# # Pre-processing of the image

# %%
img = image.load_img(filename, target_size=(224, 224))

# %%
plt.imshow(img)

# %%
resized_img.shape  #checked resized size
# Out:
# (224, 224, 3)

# %%
final_image = np.expand_dims(resized_img,axis=0) ## need forth demension
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image) #perform predictions on final image
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
#print(predictions) #did not provide labels

# %% [markdown]
# #Results has five top predictions

# %%
results = imagenet_utils.decode_predictions(predictions)
print(results)
# Out:
# [[('n04286575', 'spotlight', 0.26935866), ('n03729826', 'matchstick', 0.03132886), ('n03196217', 'digital_clock', 0.029854592), ('n03637318', 'lampshade', 0.029670017), ('n04418357', 'theater_curtain', 0.025070572)]]

# %%
plt.imshow(img);
